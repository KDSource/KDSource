# %%
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(precision=3)

import ksource_py as ks

# %%
# %matplotlib notebook

# %% [markdown]
# # Abrir tally

# %% [markdown]
# ### INPUT: Completar plantilla en una celda duplicada

# %%
# Plantilla

outputfile = "filename"
tallyname = "tally"
geomplot = "graphic.n.eps"

tally = ks.T4Tally(outputfile, tallyname, geomplot=geomplot)

# %%
# Bunker

filename = "2_bunker_n/2_bunker_n.out"
tallyname = "mapa_dosis_ne"
geomplot = "2_bunker_act/graphic.1.eps"

tally = ks.T4Tally(filename, tallyname, geomplot=geomplot)
# Out:
# Tally mapa_dosis_ne leido exitosamente

# %% [markdown]
# # Crear graficos

# %%
cell = None # Indice de celda en direccion normal a pantalla. None: promediar todas
geomplot = True # Graficar contornos de la geometria
levelcurves = [1e-6] # Curvas de nivel

[fig, [scores,errs]] = tally.plot2D(['z', 'x'], cell=cell, levelcurves=levelcurves, geomplot=True)
